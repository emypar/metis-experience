# %%
import sys
import os

# %%
import numpy as np

# %%
import mnist_test_gear

# %%
from sklearn.decomposition import \
    PCA

# %%
X_train, y_train, X_test, y_test = mnist_test_gear.get_mnist_sets()
X_train = X_train / 255
# Out:
# train size=5996, test size=996

# %%
pca = PCA()
pca.fit(X_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
np.count_nonzero(pca.explained_variance_ > 1e-10)
# Out:
# 642

# %%
pca.explained_variance_
# Out:
# array([  5.18689630e+00,   3.70796797e+00,   3.18313261e+00,
#          2.85064754e+00,   2.50723413e+00,   2.28223216e+00,
#          1.68798067e+00,   1.56849036e+00,   1.49104438e+00,
#          1.25774615e+00,   1.13702356e+00,   1.06928736e+00,
#          9.07614792e-01,   8.64973820e-01,   8.33922409e-01,
#          7.83681459e-01,   7.02942989e-01,   6.99569739e-01,
#          6.23458475e-01,   5.78821623e-01,   5.75397065e-01,
#          5.38966891e-01,   5.02779591e-01,   4.68968258e-01,
#          4.62680155e-01,   4.40101120e-01,   4.35588440e-01,
#          4.10250693e-01,   3.95925733e-01,   3.72384863e-01,
#          3.43555615e-01,   3.34495018e-01,   3.16124991e-01,
#          3.06619977e-01,   2.96695176e-01,   2.87950389e-01,
#          2.67914258e-01,   2.62324693e-01,   2.55027157e-01,
#          2.55021727e-01,   2.40044951e-01,   2.29789489e-01,
#          2.23773478e-01,   2.11140401e-01,   2.07290431e-01,
# ...
